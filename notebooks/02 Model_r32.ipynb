# %% [markdown]
# ## Portfolio - Predicción de goles en partidos FIFA WC26
#
# ### Limpieza de datos,  Modelación y Predicción de goles
#
# En este paso se realizan los siguientes pasos:
#
# 1. Conexión API a los partidos FIFA WC26
# 2. Limpieza y transformación de columnas
# 3. Creación de variables para el modelo
# 3. Modelación
# 4. Predicción Partidos

# %% [markdown]
# Paso 1 - Librerias a importar
#
# - Pandas
# - numpy
# - requests
# - utils2.py (archivo con funciones de limpieza y captura de datos)

# %%
import pandas as pd
from datetime import datetime
import numpy as np
import pandas as pd
import requests
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import statsmodels.api as sm
import statsmodels.formula.api as smf

import utils2 as utils

# %% [markdown]
# Paso 2 - Obtener datos FIFA WC26 por API (partidos, games y estadios)
#
# [Revisar repo - Github FIFA WC26 API](https://github.com/rezarahiminia/worldcup2026)

# %%
# 1. Obtener los próximos partidos (vía API o descarga directa)
url_g = "https://worldcup26.ir/get/games"
url_t = "https://worldcup26.ir/get/teams"
url_s = "https://worldcup26.ir/get/stadiums"

response = requests.get(url_g)
calendario = response.json()
response = requests.get(url_t)
teams = response.json()
response = requests.get(url_s)
stadiums = response.json()

#Paises y Estadios
dict_estadios = utils.crear_diccionario_estadios(stadiums)
id_to_fifa = {team['id']: team['fifa_code'] for team in teams['teams']}
name_to_fifa = {team['id']: team['name_en'] for team in teams['teams']}

# %% [markdown]
# Estandarizar BBDD FIFA WC26

# %%
df_wc = utils.preparar_calendario(calendario['games'])
df_wc = df_wc[df_wc['Team_id'] != "0"].copy() #Descarta partidos sin asignación de equipos
df_wc['Team'] = df_wc['Team_id'].map(id_to_fifa)
df_wc['Date'] = pd.to_datetime(df_wc['Date']).dt.strftime("%Y-%m-%d")
df_wc['Game_type'] = 'FIFA WC26'
df_wc['Venue'] = df_wc['stadium_id'].map(dict_estadios)
df_wc['Condition'] = np.where(df_wc['Team'].isin(['CAN','MEX','USA']), 'L', 'N')
df_wc['Opponent'] = df_wc['Opponent_id'].map(name_to_fifa)
df_wc['Goals_team'] = pd.to_numeric(df_wc['home_score'], errors='coerce')
df_wc['Goals_opponent'] = pd.to_numeric(df_wc['away_score'], errors='coerce')
df_wc['Penalties'] = False
df_wc['AET'] = False
df_wc = df_wc[['Team', 'Date', 'Game_type', 'Venue', 'Condition', 'Opponent', 
        'Goals_team', 'Goals_opponent', 'Penalties','AET']].copy()

# %% [markdown]
# Juntar BBDD para transformación y limpieza

# %%
df_games = pd.read_parquet('../database/games.parquet').drop(columns=['Resultado_Original'])
df_games = df_games[pd.to_datetime(df_games['Date']).dt.date < pd.Timestamp('2026-06-11').date()].copy()
df_games = pd.concat([df_games, df_wc])

# %% [markdown]
# Paso 3 - Limpieza y transformacion de variables

# %%
# Codigo FIFA Oponente
country_dict = pd.read_parquet('../database/ranking_fifa.parquet').set_index('Seleccion')['Codigo_Pais'].to_dict()
mapa_final = country_dict | utils.mapa_nombres

df_games['Opponent2'] = df_games['Opponent'].map(mapa_final)
df_games = df_games[df_games['Opponent2'].notna()].copy()

df_games['Goals_team'].fillna(0, inplace=True)
df_games['Goals_opponent'].fillna(0, inplace=True)

# Torneos
df_games['Game_type'] = df_games['Game_type'].apply(utils.reclass_torneos)
print(df_games['Game_type'].value_counts())
# Out:
# Game_type
# Friendly          579
# Federation Cup    567
# WC Qualifiers     517
# Nations League    211
# World Cup         176
# Other             136
# Name: count, dtype: int64

# %% [markdown]
# Filtro selecciones que quedan

# %%
teams_r32 = ['ALG', 'ARG', 'AUS', 'AUT', 'BEL', 'BIH', 'BRA', 'CAN', 'CIV', 'COD', 'COL', 'CPV', 'CRO', 'ECU', 'EGY', 'ENG', 'ESP', 'FRA', 'GER', 'GHA', 'JPN', 'MAR', 'MEX', 'NED', 'NOR', 'PAR', 'POR', 'RSA', 'SEN', 'SUI', 'SWE', 'USA']
df_games = df_games[df_games['Team'].isin(teams_r32)].copy()
print(df_games['Game_type'].value_counts())
# Out:
# Game_type
# Federation Cup    414
# Friendly          391
# WC Qualifiers     309
# Nations League    142
# World Cup         128
# Other              76
# Name: count, dtype: int64

# %% [markdown]
# 4 - Creación variables al modelo

# %% [markdown]
# Las variables a utilizar son las siguientes:
#
# **Fecha**: Se utilizará un decaimiento exponencial a la diferencia en días entre el 20/Jul/26 (Día posterior a la final FIFA WC26) y el día del partido.
#
# **Es_Local**: Variable binaria si el equipo está en condición de local.
#
# **AET_LastGame**: Variable binaria que indica si el partido anterior hubo alarge (Added Extra Time - AET).
#
# **Game_type**: Tipo de competicion (Amistoso, Clasificatoria, Copa de Federaciones (Euro, America, Asia, ...))
#
# **goals_team_avg**: N goles convertidos por el equipo en los últimos 5 partidos.
#
# **goals_avg**: N goles convertidos en los últimos 5 partidos

# %%
last_games = 3
df_games = utils.calcular_decaimiento_exponencial(df_games, alpha=0.01)
df_games['Es_Local'] = (df_games['Condition'] == 'L').astype(int)
df_games = utils.crear_ventana_fatiga(df_games)
df_games = utils.calcular_estadisticas_moviles(df_games, ventana=last_games)
df_games['Weight'] = df_games['Game_type'].apply(utils.asignar_peso)
df_games = df_games.dropna()
print(df_games.shape)
# Out:
# (1460, 17)

# %% [markdown]
# **z-score_rank**: Diferencia estandarizada en el ranking FIFA entre la selección y su equipo Oponente. En vez de usar el nmro de ranking, se usan los puntos FIFA.
#
# Para ello se usa el último ranking FIFA, se calcula la diferencia en puntos entre la selección y su oponente. Al ser una variable numérica, se estandariza en media y varianza.
#
# Adicionalmente, para descartar datos anómalos, se descartan partidos con más de 10 goles y partidos con diferencia en puntos FIFA muy alto (Diferencia en ptos FIFA entre -650 y 650 ptos).

# %%
scaler = StandardScaler()
df_ranking = pd.read_parquet('../database/ranking_fifa.parquet')
ranking_dict = dict(zip(df_ranking['Codigo_Pais'], df_ranking['Puntos_FIFA']))

df_games['Ranking_Team'] = df_games['Team'].map(ranking_dict)
df_games['Ranking_Opponent'] = df_games['Opponent2'].map(ranking_dict)
df_games['Ranking_diff'] = df_games['Ranking_Team'] - df_games['Ranking_Opponent']

df_games = df_games[df_games['Goals_team'] < 9].copy() #Descartar partidos con más de 10 goles

df_games = df_games[(df_games['Ranking_diff'] < 650)&(df_games['Ranking_diff'] > -650)].copy() #Descartar partidos con más de 10 goles
df_games['Zscore_Rank'] = scaler.fit_transform(df_games[['Ranking_diff']])
print(df_games.shape)
# Out:
# (1398, 21)

# %% [markdown]
# Separar datos de predicción con los de entrenamiento
#
# Los datos de predicción son los partidos que aún no se realizan

# %%
date_filter = df_games['Date'].dt.normalize() < (pd.Timestamp.now()).normalize()

df_train = df_games[date_filter].copy()
df_test = df_games[~date_filter].copy()

# %%
df_train[df_train['Game_type']=='World Cup'].sort_values(by='Date')
# Out:
#     Team       Date  Game_type  \
# 112  MEX 2026-06-11  World Cup
# 113  RSA 2026-06-11  World Cup
# 52   USA 2026-06-12  World Cup
# 53   PAR 2026-06-12  World Cup
# 159  BIH 2026-06-12  World Cup
# ..   ...        ...        ...
# 175  GHA 2026-06-27  World Cup
# 101  ARG 2026-06-27  World Cup
# 176  ALG 2026-06-27  World Cup
# 174  CRO 2026-06-27  World Cup
# 41   ENG 2026-06-27  World Cup
#
#                                                  Venue Condition  \
# 112                Estadio Azteca, Mexico City, Mexico         L
# 113                Estadio Azteca, Mexico City, Mexico         N
# 52   SoFi Stadium, Los Angeles (Inglewood), United ...         L
# 53   SoFi Stadium, Los Angeles (Inglewood), United ...         N
# 159                         BMO Field, Toronto, Canada         N
# ..                                                 ...       ...
# 175  Lincoln Financial Field, Philadelphia, United ...         N
# 101  AT&T Stadium, Dallas (Arlington, Texas), Unite...         N
# 176  GEHA Field at Arrowhead Stadium, Kansas City, ...         N
# 174  Lincoln Financial Field, Philadelphia, United ...         N
# 41   MetLife Stadium, New York/New Jersey (East Rut...         N
#
#           Opponent  Goals_team  Goals_opponent  Penalties    AET  ...  \
# 112   South Africa         2.0             0.0      False  False  ...
# 113         Mexico         0.0             2.0      False  False  ...
# 52        Paraguay         4.0             1.0      False  False  ...
# 53   United States         1.0             4.0      False  False  ...
# 159         Canada         1.0             1.0      False  False  ...
# ..             ...         ...             ...        ...    ...  ...
# 175        Croatia         1.0             2.0      False  False  ...
# 101         Jordan         3.0             1.0      False  False  ...
# 176        Austria         3.0             3.0      False  False  ...
# 174          Ghana         2.0             1.0      False  False  ...
# 41          Panama         2.0             0.0      False  False  ...
#
#     Date_decay  Es_Local  AET_LastGame  goals_team_avg  goals_avg  Weight  \
# 112   0.677057         1             0        2.666667   3.000000     0.8
# 113   0.677057         0             0        0.666667   1.666667     0.8
# 52    0.683861         1             0        1.333333   3.333333     0.8
# 53    0.683861         0             0        2.000000   2.666667     0.8
# 159   0.683861         0             0        0.666667   1.333333     0.8
# ..         ...       ...           ...             ...        ...     ...
# 175   0.794534         0             0        0.666667   1.000000     0.8
# 101   0.794534         0             0        2.666667   2.666667     0.8
# 176   0.794534         0             0        0.666667   2.000000     0.8
# 174   0.794534         0             0        1.666667   3.333333     0.8
# 41    0.794534         0             0        2.333333   3.000000     0.8
#
#      Ranking_Team  Ranking_Opponent  Ranking_diff  Zscore_Rank
# 112   1721.782405       1418.211807    303.570598     0.551298
# 113   1418.211807       1721.782405   -303.570598    -2.123951
# 52    1709.589988       1488.048969    221.541019     0.189851
# 53    1488.048969       1709.589988   -221.541019    -1.762504
# 159   1381.176640       1572.133422   -190.956782    -1.627741
# ..            ...               ...           ...          ...
# 175   1380.707809       1695.210017   -314.502208    -2.172119
# 101   1889.062265       1372.286342    516.775923     1.490746
# 176   1559.237599       1612.855967    -53.618368    -1.022586
# 174   1695.210017       1380.707809    314.502208     0.599466
# 41    1847.677458       1505.328905    342.348553     0.722165
#
# [96 rows x 21 columns]

# %%
df_test
# Out:
#     Team       Date  Game_type  \
# 107  ALG 2026-07-02  World Cup
# 44   ARG 2026-07-03  World Cup
# 46   AUS 2026-07-03  World Cup
# 137  AUT 2026-07-02  World Cup
# 202  BEL 2026-07-01  World Cup
# 181  BIH 2026-07-01  World Cup
# 102  BRA 2026-06-29  World Cup
# 133  CAN 2026-06-28  World Cup
# 196  CIV 2026-06-30  World Cup
# 201  COD 2026-07-01  World Cup
# 66   COL 2026-07-03  World Cup
# 45   CPV 2026-07-03  World Cup
# 105  CRO 2026-07-02  World Cup
# 199  ECU 2026-06-30  World Cup
# 47   EGY 2026-07-03  World Cup
# 200  ENG 2026-07-01  World Cup
# 136  ESP 2026-07-02  World Cup
# 134  FRA 2026-06-30  World Cup
# 178  GER 2026-06-29  World Cup
# 67   GHA 2026-07-03  World Cup
# 103  JPN 2026-06-29  World Cup
# 195  MAR 2026-06-29  World Cup
# 198  MEX 2026-06-30  World Cup
# 194  NED 2026-06-29  World Cup
# 197  NOR 2026-06-30  World Cup
# 179  PAR 2026-06-29  World Cup
# 104  POR 2026-07-02  World Cup
# 132  RSA 2026-06-28  World Cup
# 203  SEN 2026-07-01  World Cup
# 106  SUI 2026-07-02  World Cup
# 135  SWE 2026-06-30  World Cup
# 180  USA 2026-07-01  World Cup
#
#                                                  Venue Condition  \
# 107                        BC Place, Vancouver, Canada         N
# 44   Hard Rock Stadium, Miami (Miami Gardens), Unit...         N
# 46   AT&T Stadium, Dallas (Arlington, Texas), Unite...         N
# 137  SoFi Stadium, Los Angeles (Inglewood), United ...         N
# 202                Lumen Field, Seattle, United States         N
# 181  Levi's Stadium, San Francisco Bay Area (Santa ...         N
# 102                NRG Stadium, Houston, United States         N
# 133  SoFi Stadium, Los Angeles (Inglewood), United ...         L
# 196  AT&T Stadium, Dallas (Arlington, Texas), Unite...         N
# 201      Mercedes-Benz Stadium, Atlanta, United States         N
# 66   GEHA Field at Arrowhead Stadium, Kansas City, ...         N
# 45   Hard Rock Stadium, Miami (Miami Gardens), Unit...         N
# 105                         BMO Field, Toronto, Canada         N
# 199                Estadio Azteca, Mexico City, Mexico         N
# 47   AT&T Stadium, Dallas (Arlington, Texas), Unite...         N
# 200      Mercedes-Benz Stadium, Atlanta, United States         N
# 136  SoFi Stadium, Los Angeles (Inglewood), United ...         N
# 134  MetLife Stadium, New York/New Jersey (East Rut...         N
# 178  Gillette Stadium, Boston (Foxborough), United ...         N
# 67   GEHA Field at Arrowhead Stadium, Kansas City, ...         N
# 103                NRG Stadium, Houston, United States         N
# 195        Estadio BBVA, Monterrey (Guadalupe), Mexico         N
# 198                Estadio Azteca, Mexico City, Mexico         L
# 194        Estadio BBVA, Monterrey (Guadalupe), Mexico         N
# 197  AT&T Stadium, Dallas (Arlington, Texas), Unite...         N
# 179  Gillette Stadium, Boston (Foxborough), United ...         N
# 104                         BMO Field, Toronto, Canada         N
# 132  SoFi Stadium, Los Angeles (Inglewood), United ...         N
# 203                Lumen Field, Seattle, United States         N
# 106                        BC Place, Vancouver, Canada         N
# 135  MetLife Stadium, New York/New Jersey (East Rut...         N
# 180  Levi's Stadium, San Francisco Bay Area (Santa ...         L
#
#                              Opponent  Goals_team  Goals_opponent  Penalties  \
# 107                       Switzerland         0.0             0.0      False
# 44                         Cape Verde         0.0             0.0      False
# 46                              Egypt         0.0             0.0      False
# 137                             Spain         0.0             0.0      False
# 202                           Senegal         0.0             0.0      False
# 181                     United States         0.0             0.0      False
# 102                             Japan         0.0             0.0      False
# 133                      South Africa         0.0             0.0      False
# 196                            Norway         0.0             0.0      False
# 201                           England         0.0             0.0      False
# 66                              Ghana         0.0             0.0      False
# 45                          Argentina         0.0             0.0      False
# 105                          Portugal         0.0             0.0      False
# 199                            Mexico         0.0             0.0      False
# 47                          Australia         0.0             0.0      False
# 200  Democratic Republic of the Congo         0.0             0.0      False
# 136                           Austria         0.0             0.0      False
# 134                            Sweden         0.0             0.0      False
# 178                          Paraguay         0.0             0.0      False
# 67                           Colombia         0.0             0.0      False
# 103                            Brazil         0.0             0.0      False
# 195                       Netherlands         0.0             0.0      False
# 198                           Ecuador         0.0             0.0      False
# 194                           Morocco         0.0             0.0      False
# 197                       Ivory Coast         0.0             0.0      False
# 179                           Germany         0.0             0.0      False
# 104                           Croatia         0.0             0.0      False
# 132                            Canada         0.0             0.0      False
# 203                           Belgium         0.0             0.0      False
# 106                           Algeria         0.0             0.0      False
# 135                            France         0.0             0.0      False
# 180            Bosnia and Herzegovina         0.0             0.0      False
#
#        AET  ... Date_decay  Es_Local  AET_LastGame  goals_team_avg  goals_avg  \
# 107  False  ...   0.835270         0             0        1.666667   4.000000
# 44   False  ...   0.843665         0             0        2.666667   3.000000
# 46   False  ...   0.843665         0             0        0.666667   1.333333
# 137  False  ...   0.835270         0             0        2.000000   4.000000
# 202  False  ...   0.826959         0             0        2.000000   2.666667
# 181  False  ...   0.826959         0             0        1.666667   3.666667
# 102  False  ...   0.810584         0             0        2.333333   2.666667
# 133  False  ...   0.802519         1             0        2.666667   3.666667
# 196  False  ...   0.818731         0             0        1.333333   2.000000
# 201  False  ...   0.826959         0             0        1.333333   2.333333
# 66   False  ...   0.843665         0             0        1.333333   1.666667
# 45   False  ...   0.843665         0             0        0.666667   1.333333
# 105  False  ...   0.835270         0             0        1.666667   3.333333
# 199  False  ...   0.818731         0             0        0.666667   1.333333
# 47   False  ...   0.843665         0             0        1.666667   2.666667
# 200  False  ...   0.826959         0             0        2.000000   2.666667
# 136  False  ...   0.835270         0             0        1.666667   1.666667
# 134  False  ...   0.818731         0             0        3.333333   4.000000
# 178  False  ...   0.810584         0             0        3.333333   4.666667
# 67   False  ...   0.843665         0             0        0.666667   1.333333
# 103  False  ...   0.810584         0             0        2.333333   3.333333
# 195  False  ...   0.810584         0             0        2.000000   3.000000
# 198  False  ...   0.818731         1             0        2.000000   2.000000
# 194  False  ...   0.810584         0             0        3.333333   4.666667
# 197  False  ...   0.818731         0             0        2.666667   5.000000
# 179  False  ...   0.810584         0             0        0.666667   2.000000
# 104  False  ...   0.835270         0             0        2.000000   2.333333
# 132  False  ...   0.802519         0             0        0.666667   1.666667
# 203  False  ...   0.826959         0             0        2.666667   4.666667
# 106  False  ...   0.835270         0             0        2.333333   3.333333
# 135  False  ...   0.818731         0             0        2.333333   4.666667
# 180  False  ...   0.826959         1             0        2.666667   4.000000
#
#      Weight  Ranking_Team  Ranking_Opponent  Ranking_diff  Zscore_Rank
# 107     0.8   1559.237599       1654.939343    -95.701744    -1.208018
# 44      0.8   1889.062265       1389.785087    499.277178     1.413641
# 46      0.8   1584.552251       1570.668614     13.883637    -0.725151
# 137     0.8   1612.855967       1856.033671   -243.177704    -1.857842
# 202     0.8   1733.934577       1667.658416     66.276161    -0.494294
# 181     0.8   1381.176640       1709.589988   -328.413348    -2.233416
# 102     0.8   1765.340396       1665.943996     99.396400    -0.348356
# 133     0.8   1572.133422       1418.211807    153.921615    -0.108101
# 196     0.8   1568.623632       1577.184771     -8.561139    -0.824050
# 201     0.8   1487.183182       1847.677458   -360.494276    -2.374775
# 66      0.8   1712.604162       1380.707809    331.896353     0.676110
# 45      0.8   1389.785087       1889.062265   -499.277178    -2.986294
# 105     0.8   1695.210017       1755.093610    -59.883593    -1.050192
# 199     0.8   1570.761721       1721.782405   -151.020684    -1.451770
# 47      0.8   1570.668614       1584.552251    -13.883637    -0.847502
# 200     0.8   1847.677458       1487.183182    360.494276     0.802121
# 136     0.8   1856.033671       1612.855967    243.177704     0.285188
# 134     0.8   1887.107625       1533.186308    353.921317     0.773158
# 178     0.8   1743.544935       1488.048969    255.495966     0.339466
# 67      0.8   1380.707809       1712.604162   -331.896353    -2.248763
# 103     0.8   1665.943996       1765.340396    -99.396400    -1.224298
# 195     0.8   1755.616133       1749.204090      6.412043    -0.758073
# 198     0.8   1721.782405       1570.761721    151.020684    -0.120884
# 194     0.8   1749.204090       1755.616133     -6.412043    -0.814580
# 197     0.8   1577.184771       1568.623632      8.561139    -0.748604
# 179     0.8   1488.048969       1743.544935   -255.495966    -1.912120
# 104     0.8   1755.093610       1695.210017     59.883593    -0.522461
# 132     0.8   1418.211807       1572.133422   -153.921615    -1.464552
# 203     0.8   1667.658416       1733.934577    -66.276161    -1.078360
# 106     0.8   1654.939343       1559.237599     95.701744    -0.364636
# 135     0.8   1533.186308       1887.107625   -353.921317    -2.345812
# 180     0.8   1709.589988       1381.176640    328.413348     0.660763
#
# [32 rows x 21 columns]

# %% [markdown]
# Paso 4 - Modelación
#
# Antes de aplicar GLM Poission, revisamos descriptivamente los datos

# %% [markdown]
# Variable respuesta

# %%
# Usamos countplot en lugar de histplot para datos discretos
# Esto asegura que cada columna esté alineada exactamente con el número de goles
ax = sns.countplot(data=df_train, x='Goals_team', color='skyblue', edgecolor='black')

# Añadir etiquetas de cantidad sobre cada barra para mayor claridad
for p in ax.patches:
    if p.get_x() < 5 :
        ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, -9), 
                textcoords='offset points')
    else :
        ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2., p.get_height()), 
                ha='center', va='center', 
                xytext=(0, 9), 
                textcoords='offset points')
    
plt.title('Frecuencia Goles Marcados', fontsize=15)
plt.xlabel('#Goals', fontsize=12)
plt.ylabel('#Games', fontsize=12)
plt.savefig('../imgs/goals.png')
# Out:
# c:\Users\sarud\miniconda3\envs\ETL_update\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sarud\miniconda3\envs\ETL_update\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sarud\miniconda3\envs\ETL_update\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# Validación gráfica otras variables

# %%
vars = ['Goals_team', 'Date_decay', 'Es_Local', 'AET_LastGame', 'goals_team_avg', 'goals_avg', 'Zscore_Rank']
# Calculamos la matriz de correlación
correlacion = df_train[vars].corr()

# Creamos el mapa de calor
plt.figure(figsize=(9, 6))
sns.heatmap(correlacion, annot=True, cmap='coolwarm', vmin=-1, vmax=1, fmt=".2f")
plt.title('Mapa de Calor de Correlación entre Variables')
plt.savefig('../imgs/corr.png')

# %% [markdown]
# Modelación / Cantidad de goles ~ Modelo GLM Poisson

# %%
formula = "Goals_team ~ Date_decay + C(Game_type) + Zscore_Rank + Es_Local + goals_team_avg + goals_avg + AET_LastGame"

# Ajuste del modelo
model_1 = smf.glm(formula=formula, data=df_train, family=sm.families.Poisson()).fit()
                #var_weights=df_final['Peso_Partido']).fit()

df_model_1 = df_train.copy()
df_model_1['Prediccion'] = model_1.predict(df_model_1)
df_model_1['Error'] = df_model_1['Goals_team'] - df_model_1['Prediccion']

print(model_1.summary())
print("******* AIC:",model_1.aic,"*******")
# Visualizar si el error está centrado en 0
import matplotlib.pyplot as plt
plt.hist(df_model_1['Error'], bins=10)
plt.title("Distribución de los Errores (Residuos)")
plt.show()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             Goals_team   No. Observations:                 1366
# Model:                            GLM   Df Residuals:                     1354
# Model Family:                 Poisson   Df Model:                           11
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2193.3
# Date:               dom, 28 jun. 2026   Deviance:                       1580.2
# Time:                        14:05:23   Pearson chi2:                 1.39e+03
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1866
# Covariance Type:            nonrobust
# ==================================================================================================
#                                      coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------------------
# Intercept                          0.1924      0.066      2.910      0.004       0.063       0.322
# C(Game_type)[T.Friendly]           0.1289      0.059      2.176      0.030       0.013       0.245
# C(Game_type)[T.Nations League]     0.2278      0.074      3.088      0.002       0.083       0.372
# C(Game_type)[T.Other]              0.0194      0.099      0.195      0.845      -0.175       0.214
# C(Game_type)[T.WC Qualifiers]      0.0161      0.060      0.268      0.789      -0.101       0.134
# C(Game_type)[T.World Cup]          0.2682      0.147      1.821      0.069      -0.020       0.557
# Date_decay                         0.1480      0.165      0.895      0.371      -0.176       0.472
# Zscore_Rank                        0.3133      0.023     13.445      0.000       0.268       0.359
# Es_Local                           0.2211      0.043      5.133      0.000       0.137       0.306
# goals_team_avg                     0.0420      0.036      1.168      0.243      -0.028       0.113
# goals_avg                          0.0192      0.033      0.579      0.563      -0.046       0.084
# AET_LastGame                       0.1817      0.112      1.615      0.106      -0.039       0.402
# ==================================================================================================
# ******* AIC: 4410.605883995311 *******

# %% [markdown]
# Modelo sin variables Redundantes

# %%
formula = "Goals_team ~ Date_decay + Zscore_Rank  + goals_team_avg + goals_avg"
# Ajuste del modelo
model_2 = smf.glm(formula=formula, data=df_train, family=sm.families.Poisson()).fit()
                #var_weights=df_final['Peso_Partido']).fit()

df_model_2 = df_train.copy()
df_model_2['Prediccion'] = model_1.predict(df_model_2)
df_model_2['Error'] = df_model_2['Goals_team'] - df_model_2['Prediccion']

print(model_2.summary())
print("******* AIC:",model_2.aic,"*******")
# Visualizar si el error está centrado en 0
import matplotlib.pyplot as plt
plt.hist(df_model_2['Error'], bins=10)
plt.title("Distribución de los Errores (Residuos)")
plt.show()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             Goals_team   No. Observations:                 1366
# Model:                            GLM   Df Residuals:                     1361
# Model Family:                 Poisson   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -2214.7
# Date:               dom, 28 jun. 2026   Deviance:                       1623.1
# Time:                        14:07:58   Pearson chi2:                 1.43e+03
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1607
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          0.3346      0.057      5.895      0.000       0.223       0.446
# Date_decay         0.3047      0.091      3.335      0.001       0.126       0.484
# Zscore_Rank        0.3178      0.023     14.036      0.000       0.273       0.362
# goals_team_avg     0.0133      0.035      0.377      0.706      -0.056       0.083
# goals_avg          0.0443      0.033      1.358      0.174      -0.020       0.108
# ==================================================================================
# ******* AIC: 4439.467780607798 *******

# %% [markdown]
# Modelo con ponderador según torneo

# %%
formula = "Goals_team ~ Date_decay + Zscore_Rank + Es_Local + goals_avg"
#"Goals_team ~ Date_decay + Zscore_Rank + goals_team_avg"

# Ajuste del modelo
model_3 = smf.glm(formula=formula, data=df_train, family=sm.families.Poisson(),
                var_weights=df_train['Weight']).fit()

df_model_3 = df_train.copy()
df_model_3['Prediccion'] = model_1.predict(df_model_2)
df_model_3['Error'] = df_model_3['Goals_team'] - df_model_3['Prediccion']

print(model_3.summary())
print("******* AIC:",model_3.aic,"*******")
# Visualizar si el error está centrado en 0
import matplotlib.pyplot as plt
plt.hist(df_model_3['Error'], bins=10)
plt.title("Distribución de los Errores (Residuos)")
plt.show()
# Out:
#                  Generalized Linear Model Regression Results
# ==============================================================================
# Dep. Variable:             Goals_team   No. Observations:                 1366
# Model:                            GLM   Df Residuals:                     1361
# Model Family:                 Poisson   Df Model:                            4
# Link Function:                    Log   Scale:                          1.0000
# Method:                          IRLS   Log-Likelihood:                -1178.6
# Date:               dom, 28 jun. 2026   Deviance:                       848.42
# Time:                        14:18:41   Pearson chi2:                     747.
# No. Iterations:                     5   Pseudo R-squ. (CS):             0.1051
# Covariance Type:            nonrobust
# ===============================================================================
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       0.2436      0.081      3.024      0.002       0.086       0.401
# Date_decay      0.3993      0.115      3.486      0.000       0.175       0.624
# Zscore_Rank     0.3156      0.031     10.335      0.000       0.256       0.375
# Es_Local        0.2307      0.058      3.993      0.000       0.117       0.344
# goals_avg       0.0489      0.025      1.981      0.048       0.001       0.097
# ===============================================================================
# ******* AIC: 2367.26384840063 *******

# %% [markdown]
# Comparacion entre modelos
#
# Para ello usamos el críterio de Akaike

# %%
print(f"M1: {model_1.aic}")
print(f"M2: {model_2.aic}")
print(f"M3: {model_3.aic}")
# Out:
# M1: 4410.605883995311
# M2: 4439.467780607798
# M3: 2367.26384840063

# %% [markdown]
# El modelo es aquel con menos críterio de Akaike, es decir, el modelo con ponderador por tipo de Torneo

# %%
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(df_model_3['Goals_team'], df_model_3['Prediccion'])
print(f"Error promedio: {mae:.2f} goles por partido")
# Out:
# Error promedio: 1.06 goles por partido

# %%
# Identificar partidos donde el error es mayor a 2 goles
df_model_3['Abs_Error'] = abs(df_model_3['Error'])
fallos_graves = df_model_3.sort_values(by='Abs_Error', ascending=False).head(10)
print(fallos_graves[['Date', 'Team', 'Opponent', 'Goals_team', 'Prediccion','Ranking_diff']])
# Out:
#            Date Team                Opponent  Goals_team  Prediccion  \
# 820  2026-03-27  ALG               Guatemala         7.0    1.944727
# 1705 2023-09-08  ESP                 Georgia         7.0    2.408773
# 1941 2025-06-17  CAN                Honduras         6.0    1.429302
# 76   2025-09-09  COL               Venezuela         6.0    1.480940
# 1368 2024-03-26  AUT                  Turkey         6.0    1.591493
# 1508 2023-06-19  ENG         North Macedonia         7.0    2.711555
# 505  2024-09-05  JPN                   China         7.0    2.763232
# 1611 2024-11-16  GER  Bosnia and Herzegovina         7.0    2.764401
# 1733 2025-09-07  ESP                  Turkey         6.0    1.809021
# 1632 2023-09-07  NOR                  Jordan         6.0    2.027125
#
#       Ranking_diff
# 820     320.493849
# 1705    500.771984
# 1941    193.163121
# 76      243.426490
# 1368     33.389825
# 1508    478.518141
# 505     411.134896
# 1611    362.368295
# 1733    276.567529
# 1632    204.898429

# %% [markdown]
# Gráfico de Ranking_diff

# %%
plt.figure(figsize=(10, 6))

# Histograma con KDE para ver la distribución
sns.histplot(df_train['Zscore_Rank'], kde=True, bins=30, color='purple', edgecolor='black')

# Línea vertical en 0 (Equipos de igual ranking)
plt.axvline(0, color='red', linestyle='--', label='Ranking Igualado')

plt.title('Zscore Rank histogram', fontsize=15)
plt.xlabel('Diferencia de Ranking estand (media 0, var 1)', fontsize=12)
plt.ylabel('Cantidad de Partidos', fontsize=12)
plt.legend()
plt.savefig('../imgs/Zscore_dist.png')
# Out:
# c:\Users\sarud\miniconda3\envs\ETL_update\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# c:\Users\sarud\miniconda3\envs\ETL_update\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# Predicción próximos partidos

# %%
df_goals_upd = df_train.sort_values(['Team', 'Date']).groupby('Team').tail(last_games)
df_goals_upd['total_goals'] = df_goals_upd['Goals_team'] + df_goals_upd['Goals_opponent']
metricas_recientes = df_goals_upd.groupby('Team').agg({'Goals_team': 'mean','total_goals': 'mean'}).rename(
    columns={'total_goals':'goals_avg', 'Goals_team':'goals_team_avg'})
metricas_recientes.sample(3)

df_test = df_test.drop(columns = ['goals_team_avg', 'goals_avg']).merge(metricas_recientes, on='Team', how='left')

# %%
df_test['Model_predict'] = model_3.predict(df_test)
df_test['Goles_Estimados'] = np.where(df_test['Model_predict']<1.3, df_test['Model_predict'].astype(int), df_test['Model_predict'].round(0).astype(int))

# %%
filtro = df_test['Date'].dt.date == pd.Timestamp('2026-06-28').date()
df_hoy = df_test[filtro]
print(df_hoy[['Team', 'Opponent', 'Goles_Estimados','Model_predict']])
# Out:
#   Team      Opponent  Goles_Estimados  Model_predict
# 0  CAN  South Africa                3       2.559708
# 1  RSA        Canada                1       1.201132

# %% [markdown]
# Guardar pronóstico

# %%
df_test.to_parquet('../database/predictions_r32.parquet')
